# %% [markdown]
# # Merging and Analyzing Daily Metrics and Sleep Data

# %% [markdown]
# <div></div>

# %% [markdown]
# ## 1. Setup and Data Loading

# %%
# Import required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import json
import matplotlib.pyplot as plt

# %%
sns.set_palette('husl')

# Load data
first_df = pd.read_json('../../data/interim/slee_data_eda.json')
second_df = pd.read_json('../../data/raw/daily_metrics_2024-08-09_2024-11-17.json')

df = pd.concat([first_df, second_df])

# Display first few rows
display(df.head())
# Out:
#    userProfilePK calendarDate                              uuid  \
# 0      124522471   2024-07-30  5013d407437445bfb986f880c1e12825
# 1      124522471   2024-07-31  901d734a3c4a4026972d30e41453176a
# 2      124522471   2024-08-01  706ca3caaf414c0d9119773ad06e46f5
# 3      124522471   2024-08-02  3a554c0468474d54b86785f1097df9b2
# 4      124522471   2024-08-03  69ef647f89524e0da5fe9dae46b34168
#
#    durationInMilliseconds  totalKilocalories  activeKilocalories  \
# 0                86400000             2619.0               516.0
# 1                86400000             3026.0               923.0
# 2                86400000             2492.0               389.0
# 3                86400000             2822.0               719.0
# 4                86400000             2348.0               245.0
#
#    bmrKilocalories  wellnessKilocalories  consumedKilocalories  \
# 0           2103.0                2619.0                1722.0
# 1           2103.0                3026.0                1101.0
# 2           2103.0                2492.0                   NaN
# 3           2103.0                2822.0                   NaN
# 4           2103.0                2348.0                   NaN
#
#    remainingKilocalories  ...  \
# 0                    897  ...
# 1                   1925  ...
# 2                   2492  ...
# 3                   2822  ...
# 4                   2348  ...
#
#                                          bodyBattery  minAvgHeartRate  \
# 0  {'userProfilePK': 124522471, 'calendarDate': '...             53.0
# 1  {'userProfilePK': 124522471, 'calendarDate': '...             46.0
# 2  {'userProfilePK': 124522471, 'calendarDate': '...             48.0
# 3  {'userProfilePK': 124522471, 'calendarDate': '...             45.0
# 4  {'userProfilePK': 124522471, 'calendarDate': '...             49.0
#
#    maxAvgHeartRate   version  averageMonitoringEnvironmentAltitude  \
# 0            184.0  80040002                                  22.0
# 1            178.0  75060002                                  25.0
# 2            172.0  85920002                                  33.0
# 3            178.0  86280002                                  25.0
# 4            122.0  80340002                                  32.0
#
#                                            hydration  \
# 0  {'userProfilePK': 124522471, 'calendarDate': '...
# 1  {'userProfilePK': 124522471, 'calendarDate': '...
# 2  {'userProfilePK': 124522471, 'calendarDate': '...
# 3  {'userProfilePK': 124522471, 'calendarDate': '...
# 4                                                NaN
#
#                                          respiration  dailyTotalFromEpochData  \
# 0  {'userProfilePK': 124522471, 'calendarDate': '...                      1.0
# 1  {'userProfilePK': 124522471, 'calendarDate': '...                      NaN
# 2  {'userProfilePK': 124522471, 'calendarDate': '...                      NaN
# 3  {'userProfilePK': 124522471, 'calendarDate': '...                      NaN
# 4  {'userProfilePK': 124522471, 'calendarDate': '...                      NaN
#
#                                  bodyBatteryFeedback burnedKilocalories
# 0                                                NaN                NaN
# 1  {'userProfilePk': 124522471, 'calendarDate': {...                NaN
# 2  {'userProfilePk': 124522471, 'calendarDate': {...                NaN
# 3  {'userProfilePk': 124522471, 'calendarDate': {...                NaN
# 4  {'userProfilePk': 124522471, 'calendarDate': {...                NaN
#
# [5 rows x 55 columns]

# %% [markdown]
# <div>
#
# </div>
